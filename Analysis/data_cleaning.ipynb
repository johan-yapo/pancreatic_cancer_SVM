# %% [markdown]
# Description: Cleaning and preparing the datasets one of the protein markers for machine learning training
# Developed by: Johan A. Yapo
# Date: June 2nd 2025

# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

RNG_SEED = 8
np.random.seed(RNG_SEED)
curr_dir = os.getcwd()
DATA_PATH = os.path.join(os.path.dirname(curr_dir), 'Data')
RESULTS_PATH = os.path.join(os.path.dirname(curr_dir), 'Results')

# %%
print("DATA_PATH =", DATA_PATH)
# Out:
# DATA_PATH = c:\Users\joeya\Documents\pancreatic_cancer_SVM\Data

# %%
df =  pd.read_csv(os.path.join(DATA_PATH, "machine_learning_data_template_ca125 serum.csv"))

cols_to_avg = ['Rsol', 'Rp', 'CPE', 'CV_Area', 'Delta_Z']

# Build aggregation: mean for numeric cols, first for Class_Multimodal
agg_dict = {col: 'mean' for col in cols_to_avg}
agg_dict['Class_Multimodal'] = 'first'

# Group by 'Type' and aggregate
df_avg = df.groupby('Type').agg(agg_dict).reset_index()

# Reorder columns: Type, Class_Multimodal, then averaged metrics
df_avg = df_avg[['Type', 'Class_Multimodal'] + cols_to_avg]

# 1. Extract the integer part of each “Type” (e.g. "150 ng/ml" → 150, "0" → 0)
df_avg['conc'] = df_avg['Type'].str.extract(r'(\d+)').astype(int)

# 2. Sort by that new column, then drop it
df_avg = df_avg.sort_values('conc').drop(columns=['conc']).reset_index(drop=True)

# Now df_avg is ordered from lowest to highest concentration
print(df_avg)

# Display the result
df_avg
# Out:
#          Type Class_Multimodal       Rsol            Rp       CPE     CV_Area  \
# 0           0          Normal   40.766667  1.423667e+06  0.000007  208.433333
# 1    10 ng/ml          Normal   40.953333  1.150000e+06  0.000008  232.466667
# 2    28 ng/ml          Normal   36.583333  1.175000e+06  0.000008  166.066667
# 3    57 ng/ml          Normal   35.666667  2.113333e+06  0.000008  159.733333
# 4    90 ng/ml          Normal   34.123333  9.620000e+05  0.000008  179.466667
# 5   106 ng/ml         Low Risk  32.970000  1.130333e+06  0.000008  125.766667
# 6   120 ng/ml         Low Risk  38.643333  1.510000e+06  0.000008  188.366667
# 7   150 ng/ml         Low Risk  45.126667  3.481333e+06  0.000008  332.900000
# 8   180 ng/ml         Low Risk  49.880000  6.853333e+06  0.000008  246.166667
# 9   200 ng/ml        High Risk  39.833333  1.302000e+06  0.000007  292.466667
# 10  240 ng/ml        High Risk  50.586667  1.508000e+07  0.000008  280.733333
# 11  270 ng/ml        High Risk  56.573333  7.215667e+06  0.000008  261.200000
# 12  300 ng/ml        High Risk  33.670000  8.990000e+05  0.000007  145.333333
# 13  330 ng/ml        High Risk  57.720000  3.366667e+06  0.000007  340.633333
# 14  360 ng/ml        High Risk  50.533333  3.340000e+06  0.000008  376.533333
#
#        Delta_Z
# 0     0.000000
# 1    38.676496
# 2   101.368723
# 3   106.395271
# 4    68.696159
# 5   137.392319
# 6    95.085538
# 7   123.150432
# 8    74.979345
# 9   152.890842
# 10   51.103240
# 11   64.507369
# 12  138.648956
# 13   90.058989
# 14   58.224184
#          Type Class_Multimodal       Rsol            Rp       CPE     CV_Area  \
# 0           0          Normal   40.766667  1.423667e+06  0.000007  208.433333
# 1    10 ng/ml          Normal   40.953333  1.150000e+06  0.000008  232.466667
# 2    28 ng/ml          Normal   36.583333  1.175000e+06  0.000008  166.066667
# 3    57 ng/ml          Normal   35.666667  2.113333e+06  0.000008  159.733333
# 4    90 ng/ml          Normal   34.123333  9.620000e+05  0.000008  179.466667
# 5   106 ng/ml         Low Risk  32.970000  1.130333e+06  0.000008  125.766667
# 6   120 ng/ml         Low Risk  38.643333  1.510000e+06  0.000008  188.366667
# 7   150 ng/ml         Low Risk  45.126667  3.481333e+06  0.000008  332.900000
# 8   180 ng/ml         Low Risk  49.880000  6.853333e+06  0.000008  246.166667
# 9   200 ng/ml        High Risk  39.833333  1.302000e+06  0.000007  292.466667
# 10  240 ng/ml        High Risk  50.586667  1.508000e+07  0.000008  280.733333
# 11  270 ng/ml        High Risk  56.573333  7.215667e+06  0.000008  261.200000
# 12  300 ng/ml        High Risk  33.670000  8.990000e+05  0.000007  145.333333
# 13  330 ng/ml        High Risk  57.720000  3.366667e+06  0.000007  340.633333
# 14  360 ng/ml        High Risk  50.533333  3.340000e+06  0.000008  376.533333
#
#        Delta_Z
# 0     0.000000
# 1    38.676496
# 2   101.368723
# 3   106.395271
# 4    68.696159
# 5   137.392319
# 6    95.085538
# 7   123.150432
# 8    74.979345
# 9   152.890842
# 10   51.103240
# 11   64.507369
# 12  138.648956
# 13   90.058989
# 14   58.224184

# %%
print("DATA_PATH =", DATA_PATH)
# Out:
# DATA_PATH = c:\Users\joeya\Documents\pancreatic_cancer_SVM\Data

# %%
# Save this new dataset
# 1. Get your current directory (should be …/pancreatic_cancer_SVM/Data)
curr_dir = os.getcwd()

# 2. Build the path for the new CSV inside Data
output_path = os.path.join(curr_dir, "_averaged_machine_learning_data_template_ca125 serum.csv")

# 3. Save df_avg there
df_avg.to_csv(output_path, index=False)
